# %% [markdown]
# <a href="https://colab.research.google.com/github/SantiagoGGallardoP/Extracci-n-de-caracter-sticas/blob/main/5_Extracci%C3%B3n_de_Caracter%C3%ADsticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #A01734347
# #SANTIAGO GAEL GALLARDO PARENTE

# %%
# %pip install --upgrade pip

# %%
# !pip install funpymodeling

# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
#Carga desde un archivo .xlsx sin indice
Micro_Retailer= pd.read_excel('microretailer_mit_lift_lab.xlsx')

# %%
#Verificamos información del DataFrame
Micro_Retailer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Columns: 106 entries, _record_id to 235_email
# dtypes: float64(23), int64(2), object(81)
# memory usage: 141.7+ KB

# %%
#Imprimo los primeros 5 registro del dataframe
Micro_Retailer.head()
# Out:
#                              _record_id             _title  \
# 0  dff2998e-af74-4de6-8efd-488aca24e67b  November 12, 2022
# 1  c596412f-4fc2-4983-acba-d9565859e42f  November 12, 2022
# 2  5bb632b3-41b5-4fb6-a817-b564e8b45a48  November 12, 2022
# 3  6774a0f6-bab4-4a58-bf94-95ad0b7cb438  November 12, 2022
# 4  6cc637fa-3d54-48c7-9499-6de13d0a26aa  November 12, 2022
#
#         _server_updated_at           _updated_by  \
# 0  2022-11-12 22:15:10 UTC  Salomon Abdala Perez
# 1  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 2  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 3  2022-11-12 22:15:09 UTC  Salomon Abdala Perez
# 4  2022-11-12 22:15:08 UTC  Salomon Abdala Perez
#
#                                        _geometry  _latitude  _longitude  \
# 0   SRID=4326;POINT(-98.233822273 19.0535362706)  19.053536  -98.233822
# 1  SRID=4326;POINT(-98.2341421351 19.0535610353)  19.053561  -98.234142
# 2    SRID=4326;POINT(-98.232299887 19.058654656)  19.058655  -98.232300
# ...

# %%
df_categorico = Micro_Retailer.select_dtypes(include=['object'])

# Imprimimos el DataFrame resultante
print(df_categorico)

# %%
#Obtengo un análisis univariado de las variables categóricas
freq_tbl(Micro_Retailer)

# %% [markdown]
# #TABLA 1. Ejemplo Actividad.

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table1= freq_tbl(Micro_Retailer['214_customer_relationship_tools'])
table1
# Out:
#     214_customer_relationship_tools  frequency  percentage  cumulative_perc
# 0                    Redes sociales         27    0.157895         0.284211
# 1                  Aplicación móvil         21    0.122807         0.505263
# 2                           Ninguna         20    0.116959         0.715789
# 3   Aplicación móvil,Redes sociales         13    0.076023         0.852632
# 4                          Cuaderno          6    0.035088         0.915789
# 5                          Teléfono          1    0.005848         0.926316
# 6           Cuaderno,Redes sociales          1    0.005848         0.936842
# 7        Aplicación móvil,De frente          1    0.005848         0.947368
# 8                           Físico           1    0.005848         0.957895
# 9          Aplicación móvil,Ninguna          1    0.005848         0.968421
# 10                    publicidades           1    0.005848         0.978947
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table1[table1['frequency']>1]
Filtro
# Out:
#    214_customer_relationship_tools  frequency  percentage  cumulative_perc
# 0                   Redes sociales         27    0.157895         0.284211
# 1                 Aplicación móvil         21    0.122807         0.505263
# 2                          Ninguna         20    0.116959         0.715789
# 3  Aplicación móvil,Redes sociales         13    0.076023         0.852632
# 4                         Cuaderno          6    0.035088         0.915789

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('214_customer_relationship_tools')
Filtro_index
# Out:
#                                  frequency  percentage  cumulative_perc
# 214_customer_relationship_tools
# Redes sociales                          27    0.157895         0.284211
# Aplicación móvil                        21    0.122807         0.505263
# Ninguna                                 20    0.116959         0.715789
# Aplicación móvil,Redes sociales         13    0.076023         0.852632
# Cuaderno                                 6    0.035088         0.915789

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('Herramientas de relación con los clientes')
plt.xlabel('Tipo de Herramienta')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='214_customer_relationship_tools'>

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %%
#Realizamos grafico hexagonal del dataframe filtrado, alternativo al scatter plot
Filtro_index.plot.hexbin("frequency", "cumulative_perc", figsize=(10,5))
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# #TABLA 2. Limpieza muebles.

# %%
muebles = Micro_Retailer["157_frequency_organize_shelves"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table2= freq_tbl(muebles)
table2
# Out:
#   157_frequency_organize_shelves  frequency  percentage  cumulative_perc
# 0                 datos omitidos         75    0.438596         0.438596
# 1                   Semanalmente         40    0.233918         0.672515
# 2                    Diariamente         32    0.187135         0.859649
# 3                          Nunca          8    0.046784         0.906433
# 4                   Mensualmente          7    0.040936         0.947368
# 5                 Quincenalmente          5    0.029240         0.976608
# 6                     Anualmente          2    0.011696         0.988304
# 7                 Semestralmente          1    0.005848         0.994152
# 8                    No se tiene          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table2[table2['frequency']>1]
Filtro
# Out:
#   157_frequency_organize_shelves  frequency  percentage  cumulative_perc
# 0                 datos omitidos         75    0.438596         0.438596
# 1                   Semanalmente         40    0.233918         0.672515
# 2                    Diariamente         32    0.187135         0.859649
# 3                          Nunca          8    0.046784         0.906433
# 4                   Mensualmente          7    0.040936         0.947368
# 5                 Quincenalmente          5    0.029240         0.976608
# 6                     Anualmente          2    0.011696         0.988304

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('157_frequency_organize_shelves')
Filtro_index
# Out:
#                                 frequency  percentage  cumulative_perc
# 157_frequency_organize_shelves
# datos omitidos                         75    0.438596         0.438596
# Semanalmente                           40    0.233918         0.672515
# Diariamente                            32    0.187135         0.859649
# Nunca                                   8    0.046784         0.906433
# Mensualmente                            7    0.040936         0.947368
# Quincenalmente                          5    0.029240         0.976608
# Anualmente                              2    0.011696         0.988304

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Constancia de limpieza muebles')
# Out:
# Text(0.5, 1.0, 'Constancia de limpieza muebles')

# %% [markdown]
# ## HALLAZGO: Dentro de las sucursales, la temporalidad dentro de las que se realizan las limpiezas de muebles son semanalmente, seguido de diariamente y nunca.

# %% [markdown]
# #TABLA 3. Pago proveedores.

# %%
pagos = Micro_Retailer["277_payment_method_suppliers"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table3= freq_tbl(pagos)
table3
# Out:
#                         277_payment_method_suppliers  frequency  percentage  \
# 0                                     datos omitidos        103    0.602339
# 1                                           Efectivo         43    0.251462
# 2               Efectivo,Transferencia interbancaria          8    0.046784
# 3                        Transferencia interbancaria          7    0.040936
# 4             Efectivo,Tarjeta de débito y/o crédito          4    0.023392
# 5                      Tarjeta de débito y/o crédito          4    0.023392
# 6  Efectivo,Tarjeta de débito y/o crédito,Transfe...          2    0.011696
#
#    cumulative_perc
# 0         0.602339
# 1         0.853801
# 2         0.900585
# 3         0.941520
# 4         0.964912
# 5         0.988304
# 6         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table3[table3['frequency']>1]
Filtro
# Out:
#                         277_payment_method_suppliers  frequency  percentage  \
# 0                                     datos omitidos        103    0.602339
# 1                                           Efectivo         43    0.251462
# 2               Efectivo,Transferencia interbancaria          8    0.046784
# 3                        Transferencia interbancaria          7    0.040936
# 4             Efectivo,Tarjeta de débito y/o crédito          4    0.023392
# 5                      Tarjeta de débito y/o crédito          4    0.023392
# 6  Efectivo,Tarjeta de débito y/o crédito,Transfe...          2    0.011696
#
#    cumulative_perc
# 0         0.602339
# 1         0.853801
# 2         0.900585
# 3         0.941520
# 4         0.964912
# 5         0.988304
# 6         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('277_payment_method_suppliers')
Filtro_index
# Out:
#                                                     frequency  percentage  \
# 277_payment_method_suppliers
# datos omitidos                                            103    0.602339
# Efectivo                                                   43    0.251462
# Efectivo,Transferencia interbancaria                        8    0.046784
# Transferencia interbancaria                                 7    0.040936
# Efectivo,Tarjeta de débito y/o crédito                      4    0.023392
# Tarjeta de débito y/o crédito                               4    0.023392
# Efectivo,Tarjeta de débito y/o crédito,Transfer...          2    0.011696
#
#                                                     cumulative_perc
# 277_payment_method_suppliers
# datos omitidos                                             0.602339
# Efectivo                                                   0.853801
# Efectivo,Transferencia interbancaria                       0.900585
# ...

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('métodos de pago')
# Out:
# Text(0.5, 1.0, 'métodos de pago')

# %% [markdown]
# ## HALLAZGO: Dentro de las sucursales, la manera más común de transacciones entre proveedores es en efectivo, seguido de transferencias interbancarias.

# %% [markdown]
# #TABLA 4. Herramientas de planificación de adquisiciones

# %%
herramientas = Micro_Retailer["192_procurement_planning_tools"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table4= freq_tbl(herramientas)
table4
# Out:
#            192_procurement_planning_tools  frequency  percentage  \
# 0                          datos omitidos        103    0.602339
# 1                                Cuaderno         25    0.146199
# 2                                 Ninguna         24    0.140351
# 3                                   Excel          6    0.035088
# 4                  Software especializado          4    0.023392
# 5               Aplicación móvil,Cuaderno          2    0.011696
# 6                          Cuaderno,Excel          2    0.011696
# 7                        Aplicación móvil          1    0.005848
# 8                             Mentalmente          1    0.005848
# 9   Cuaderno,Excel,Software especializado          1    0.005848
# 10                              catálogo           1    0.005848
# 11                         Compra directa          1    0.005848
#
#     cumulative_perc
# 0          0.602339
# 1          0.748538
# 2          0.888889
# 3          0.923977
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table4[table4['frequency']>1]
Filtro
# Out:
#   192_procurement_planning_tools  frequency  percentage  cumulative_perc
# 0                 datos omitidos        103    0.602339         0.602339
# 1                       Cuaderno         25    0.146199         0.748538
# 2                        Ninguna         24    0.140351         0.888889
# 3                          Excel          6    0.035088         0.923977
# 4         Software especializado          4    0.023392         0.947368
# 5      Aplicación móvil,Cuaderno          2    0.011696         0.959064
# 6                 Cuaderno,Excel          2    0.011696         0.970760

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('192_procurement_planning_tools')
Filtro_index
# Out:
#                                 frequency  percentage  cumulative_perc
# 192_procurement_planning_tools
# datos omitidos                        103    0.602339         0.602339
# Cuaderno                               25    0.146199         0.748538
# Ninguna                                24    0.140351         0.888889
# Excel                                   6    0.035088         0.923977
# Software especializado                  4    0.023392         0.947368
# Aplicación móvil,Cuaderno               2    0.011696         0.959064
# Cuaderno,Excel                          2    0.011696         0.970760

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Herramientas de planificación de adquisiciones')
# Out:
# Text(0.5, 1.0, 'Herramientas de planificación de adquisiciones')

# %% [markdown]
# ## HALLAZGO: Como podemos observar, la mayor parte de los participantes siguen haciendo su planificación de manrea manual, lo cual arroja información sobre el desapego que podría limitar las posibilidades de evolución con las sucursales. Incluso no tener ninguna es más popular que cualquier herramienta empleada aparte de hacerlo a mano.

# %% [markdown]
# #TABLA 5. órdenes para proveedores

# %%
ordenes = Micro_Retailer["185_place_orders_suppliers"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table5= freq_tbl(ordenes)
table5
# Out:
#                            185_place_orders_suppliers  frequency  percentage  \
# 0                                      datos omitidos        100    0.584795
# 1                                          En persona         20    0.116959
# 2              Mensajería instantánea (e.g. WhatsApp)          8    0.046784
# 3   En persona,Llamada telefónica,Mensajería insta...          7    0.040936
# 4                                  Llamada telefónica          6    0.035088
# 5   En persona,Mensajería instantánea (e.g. WhatsApp)          5    0.029240
# 6                            Página web del proveedor          5    0.029240
# 7                       En persona,Llamada telefónica          5    0.029240
# 8   Mensaje de texto (SMS),Mensajería instantánea ...          2    0.011696
# 9                 En persona,Página web del proveedor          2    0.011696
# 10                             Mensaje de texto (SMS)          2    0.011696
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table5[table5['frequency']>1]
Filtro
# Out:
#                            185_place_orders_suppliers  frequency  percentage  \
# 0                                      datos omitidos        100    0.584795
# 1                                          En persona         20    0.116959
# 2              Mensajería instantánea (e.g. WhatsApp)          8    0.046784
# 3   En persona,Llamada telefónica,Mensajería insta...          7    0.040936
# 4                                  Llamada telefónica          6    0.035088
# 5   En persona,Mensajería instantánea (e.g. WhatsApp)          5    0.029240
# 6                            Página web del proveedor          5    0.029240
# 7                       En persona,Llamada telefónica          5    0.029240
# 8   Mensaje de texto (SMS),Mensajería instantánea ...          2    0.011696
# 9                 En persona,Página web del proveedor          2    0.011696
# 10                             Mensaje de texto (SMS)          2    0.011696
#
#     cumulative_perc
# 0          0.584795
# ...

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('185_place_orders_suppliers')
Filtro_index
# Out:
#                                                     frequency  percentage  \
# 185_place_orders_suppliers
# datos omitidos                                            100    0.584795
# En persona                                                 20    0.116959
# Mensajería instantánea (e.g. WhatsApp)                      8    0.046784
# En persona,Llamada telefónica,Mensajería instan...          7    0.040936
# Llamada telefónica                                          6    0.035088
# En persona,Mensajería instantánea (e.g. WhatsApp)           5    0.029240
# Página web del proveedor                                    5    0.029240
# En persona,Llamada telefónica                               5    0.029240
# Mensaje de texto (SMS),Mensajería instantánea (...          2    0.011696
# En persona,Página web del proveedor                         2    0.011696
# Mensaje de texto (SMS)                                      2    0.011696
#
# ...

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('185_place_orders_suppliers')
# Out:
# Text(0.5, 1.0, '185_place_orders_suppliers')

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
plt.title('185_place_orders_suppliers')
# Out:
# Text(0.5, 1.0, '185_place_orders_suppliers')

# %% [markdown]
# ## HALLAZGO: La mayoría de los proveedores reciben sus órdenes de manera presencial, seguida por alguna app de mensajería como whatsapp y por llamadas.

# %% [markdown]
# #TABLA 6. Recepción de paquetes.

# %%
delivery = Micro_Retailer["314_reception_delivery_packages"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table6= freq_tbl(delivery)
table6
# Out:
#   314_reception_delivery_packages  frequency  percentage  cumulative_perc
# 0                  datos omitidos        103    0.602339         0.602339
# 1        Totalmente en desacuerdo         46    0.269006         0.871345
# 2                 Algo de acuerdo          9    0.052632         0.923977
# 3           Totalmente de acuerdo          8    0.046784         0.970760
# 4  Ni de acuerdo ni en desacuerdo          3    0.017544         0.988304
# 5              Algo en desacuerdo          2    0.011696         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table6[table6['frequency']>1]
Filtro
# Out:
#   314_reception_delivery_packages  frequency  percentage  cumulative_perc
# 0                  datos omitidos        103    0.602339         0.602339
# 1        Totalmente en desacuerdo         46    0.269006         0.871345
# 2                 Algo de acuerdo          9    0.052632         0.923977
# 3           Totalmente de acuerdo          8    0.046784         0.970760
# 4  Ni de acuerdo ni en desacuerdo          3    0.017544         0.988304
# 5              Algo en desacuerdo          2    0.011696         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('314_reception_delivery_packages')
Filtro_index
# Out:
#                                  frequency  percentage  cumulative_perc
# 314_reception_delivery_packages
# datos omitidos                         103    0.602339         0.602339
# Totalmente en desacuerdo                46    0.269006         0.871345
# Algo de acuerdo                          9    0.052632         0.923977
# Totalmente de acuerdo                    8    0.046784         0.970760
# Ni de acuerdo ni en desacuerdo           3    0.017544         0.988304
# Algo en desacuerdo                       2    0.011696         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('314_reception_delivery_packages')
# Out:
# Text(0.5, 1.0, '314_reception_delivery_packages')

# %% [markdown]
# ##HALLAZGO: La mayoría de los locales no cuentan con un servicio de entrega de mercancía, seguido por algunos puntuales que podrían considerar este servicio, dependería del giro de la sucursal por ejemplo

# %% [markdown]
# #TABLA 7. Entregas a casa.

# %%
home = Micro_Retailer["313_home_deliveries"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table7= freq_tbl(home)
table7
# Out:
#               313_home_deliveries  frequency  percentage  cumulative_perc
# 0                  datos omitidos        113    0.660819         0.660819
# 1        Totalmente en desacuerdo         25    0.146199         0.807018
# 2           Totalmente de acuerdo         14    0.081871         0.888889
# 3                 Algo de acuerdo         11    0.064327         0.953216
# 4              Algo en desacuerdo          5    0.029240         0.982456
# 5  Ni de acuerdo ni en desacuerdo          3    0.017544         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table7[table7['frequency']>1]
Filtro
# Out:
#               313_home_deliveries  frequency  percentage  cumulative_perc
# 0                  datos omitidos        113    0.660819         0.660819
# 1        Totalmente en desacuerdo         25    0.146199         0.807018
# 2           Totalmente de acuerdo         14    0.081871         0.888889
# 3                 Algo de acuerdo         11    0.064327         0.953216
# 4              Algo en desacuerdo          5    0.029240         0.982456
# 5  Ni de acuerdo ni en desacuerdo          3    0.017544         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('313_home_deliveries')
Filtro_index
# Out:
#                                 frequency  percentage  cumulative_perc
# 313_home_deliveries
# datos omitidos                        113    0.660819         0.660819
# Totalmente en desacuerdo               25    0.146199         0.807018
# Totalmente de acuerdo                  14    0.081871         0.888889
# Algo de acuerdo                        11    0.064327         0.953216
# Algo en desacuerdo                      5    0.029240         0.982456
# Ni de acuerdo ni en desacuerdo          3    0.017544         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Entregas a domicilio')
# Out:
# Text(0.5, 1.0, 'Entregas a domicilio')

# %% [markdown]
# ##HALLAZGOS: La mayoría de las sucursales no cuentan con servicio de entregas a domicilio

# %% [markdown]
# #TABLA 8. Nuevos servicios.

# %%
services = Micro_Retailer["60_services"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table8= freq_tbl(services)
table8
# Out:
#                                           60_services  frequency  percentage  \
# 0                                      datos omitidos         94    0.549708
# 1                                             Ninguno         44    0.257310
# 2                                 Entrega a domicilio         15    0.087719
# 3                                  Recarga telefónica          7    0.040936
# 4   Entrega a domicilio,Pago de servicios públicos...          2    0.011696
# 5              Entrega a domicilio,Recarga telefónica          2    0.011696
# 6                                Toma de papa nicolau          1    0.005848
# 7                                      Renta de local          1    0.005848
# 8                                               venta          1    0.005848
# 9   Entrega a domicilio,Recarga telefónica,Recepci...          1    0.005848
# 10  Entrega a domicilio,Pago de servicios públicos...          1    0.005848
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table8[table8['frequency']>1]
Filtro
# Out:
#                                          60_services  frequency  percentage  \
# 0                                     datos omitidos         94    0.549708
# 1                                            Ninguno         44    0.257310
# 2                                Entrega a domicilio         15    0.087719
# 3                                 Recarga telefónica          7    0.040936
# 4  Entrega a domicilio,Pago de servicios públicos...          2    0.011696
# 5             Entrega a domicilio,Recarga telefónica          2    0.011696
#
#    cumulative_perc
# 0         0.549708
# 1         0.807018
# 2         0.894737
# 3         0.935673
# 4         0.947368
# 5         0.959064

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('60_services')
Filtro_index
# Out:
#                                                     frequency  percentage  \
# 60_services
# datos omitidos                                             94    0.549708
# Ninguno                                                    44    0.257310
# Entrega a domicilio                                        15    0.087719
# Recarga telefónica                                          7    0.040936
# Entrega a domicilio,Pago de servicios públicos ...          2    0.011696
# Entrega a domicilio,Recarga telefónica                      2    0.011696
#
#                                                     cumulative_perc
# 60_services
# datos omitidos                                             0.549708
# Ninguno                                                    0.807018
# Entrega a domicilio                                        0.894737
# Recarga telefónica                                         0.935673
# Entrega a domicilio,Pago de servicios públicos ...         0.947368
# ...

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('60_services')
# Out:
# Text(0.5, 1.0, '60_services')

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='60_services'>

# %% [markdown]
# ##HALLAZGOS: Como se puede observar la mayoría de los locales no tiene algún interés por implementar nuevos servicios de manera urgente

# %% [markdown]
# #TABLA 9. Presencia en ecommerce.

# %%
plataf = Micro_Retailer["227_agreement_ecommerce_platforms"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table9= freq_tbl(plataf)
table9
# Out:
#   227_agreement_ecommerce_platforms  frequency  percentage  cumulative_perc
# 0                                no         88    0.514620          0.51462
# 1                    datos omitidos         73    0.426901          0.94152
# 2                               yes         10    0.058480          1.00000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table9[table9['frequency']>1]
Filtro
# Out:
#   227_agreement_ecommerce_platforms  frequency  percentage  cumulative_perc
# 0                                no         88    0.514620          0.51462
# 1                    datos omitidos         73    0.426901          0.94152
# 2                               yes         10    0.058480          1.00000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('227_agreement_ecommerce_platforms')
Filtro_index
# Out:
#                                    frequency  percentage  cumulative_perc
# 227_agreement_ecommerce_platforms
# no                                        88    0.514620          0.51462
# datos omitidos                            73    0.426901          0.94152
# yes                                       10    0.058480          1.00000

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='227_agreement_ecommerce_platforms'>

# %% [markdown]
# ##HALLAZGOS: Si bien la cantidad de datos omitidos en esta pregunta es muy significante, la mayoría de los establecimientos no cuentan con etsrategias de ecommerce o alizanas estrategicas con presencia en internet.

# %% [markdown]
# #TABLA 10. Herramientas para planeación de ventas.

# %%
sales = Micro_Retailer["193_sales_planning_tools"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table10= freq_tbl(sales)
table10
# Out:
#                    193_sales_planning_tools  frequency  percentage  \
# 0                            datos omitidos         89    0.520468
# 1                                   Ninguna         33    0.192982
# 2                                  Cuaderno         21    0.122807
# 3                    Software especializado          6    0.035088
# 4                                     Excel          6    0.035088
# 5                            Cuaderno,Excel          3    0.017544
# 6                          Cuaderno,Ninguna          2    0.011696
# 7                                     Other          1    0.005848
# 8                                    Mental          1    0.005848
# 9                      Por temporada de pan          1    0.005848
# 10                           Sobre demanda           1    0.005848
# 11  Aplicación móvil,Software especializado          1    0.005848
# 12             Excel,Software especializado          1    0.005848
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table10[table10['frequency']>1]
Filtro
# Out:
#   193_sales_planning_tools  frequency  percentage  cumulative_perc
# 0           datos omitidos         89    0.520468         0.520468
# 1                  Ninguna         33    0.192982         0.713450
# 2                 Cuaderno         21    0.122807         0.836257
# 3   Software especializado          6    0.035088         0.871345
# 4                    Excel          6    0.035088         0.906433
# 5           Cuaderno,Excel          3    0.017544         0.923977
# 6         Cuaderno,Ninguna          2    0.011696         0.935673

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('193_sales_planning_tools')
Filtro_index
# Out:
#                           frequency  percentage  cumulative_perc
# 193_sales_planning_tools
# datos omitidos                   89    0.520468         0.520468
# Ninguna                          33    0.192982         0.713450
# Cuaderno                         21    0.122807         0.836257
# Software especializado            6    0.035088         0.871345
# Excel                             6    0.035088         0.906433
# Cuaderno,Excel                    3    0.017544         0.923977
# Cuaderno,Ninguna                  2    0.011696         0.935673

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Herramientas planeación ventas')
# Out:
# Text(0.5, 1.0, 'Herramientas planeación ventas')

# %% [markdown]
# ##HALLAZGOS: Las sucursales presentan un comportamiento en el que se omite el uso de herramientas para una planeación estrategica de ventas, seguido por algunos que emplean un cuaderno como material o bien a mano mientras que por último casi nadie usa softwares especializados.

# %% [markdown]
# #TABLA 11. Créditos a clientes.

# %%
credit = Micro_Retailer["33_credit_to_customers"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table11= freq_tbl(credit)
table11
# Out:
#   33_credit_to_customers  frequency  percentage  cumulative_perc
# 0                     no         80    0.467836         0.467836
# 1         datos omitidos         64    0.374269         0.842105
# 2                    yes         27    0.157895         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table11[table11['frequency']>1]
Filtro
# Out:
#   33_credit_to_customers  frequency  percentage  cumulative_perc
# 0                     no         80    0.467836         0.467836
# 1         datos omitidos         64    0.374269         0.842105
# 2                    yes         27    0.157895         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('33_credit_to_customers')
Filtro_index
# Out:
#                         frequency  percentage  cumulative_perc
# 33_credit_to_customers
# no                             80    0.467836         0.467836
# datos omitidos                 64    0.374269         0.842105
# yes                            27    0.157895         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('33_credit_to_customers')
# Out:
# Text(0.5, 1.0, '33_credit_to_customers')

# %% [markdown]
# ##HALLAZGOS: Sólo contados establecimientos cuentan con un servicio de créditos para los clientes, mientras que en su mayoría no tienen si quiera contemplado dicho servicio.

# %% [markdown]
# #TABLA 12. Relaciones clientes.

# %%
ctools = Micro_Retailer["214_customer_relationship_tools"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table12= freq_tbl(ctools)
table12
# Out:
#     214_customer_relationship_tools  frequency  percentage  cumulative_perc
# 0                    datos omitidos         76    0.444444         0.444444
# 1                    Redes sociales         27    0.157895         0.602339
# 2                  Aplicación móvil         21    0.122807         0.725146
# 3                           Ninguna         20    0.116959         0.842105
# 4   Aplicación móvil,Redes sociales         13    0.076023         0.918129
# 5                          Cuaderno          6    0.035088         0.953216
# 6                          Teléfono          1    0.005848         0.959064
# 7           Cuaderno,Redes sociales          1    0.005848         0.964912
# 8        Aplicación móvil,De frente          1    0.005848         0.970760
# 9                           Físico           1    0.005848         0.976608
# 10         Aplicación móvil,Ninguna          1    0.005848         0.982456
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table12[table12['frequency']>1]
Filtro
# Out:
#    214_customer_relationship_tools  frequency  percentage  cumulative_perc
# 0                   datos omitidos         76    0.444444         0.444444
# 1                   Redes sociales         27    0.157895         0.602339
# 2                 Aplicación móvil         21    0.122807         0.725146
# 3                          Ninguna         20    0.116959         0.842105
# 4  Aplicación móvil,Redes sociales         13    0.076023         0.918129
# 5                         Cuaderno          6    0.035088         0.953216

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('214_customer_relationship_tools')
Filtro_index
# Out:
#                                  frequency  percentage  cumulative_perc
# 214_customer_relationship_tools
# datos omitidos                          76    0.444444         0.444444
# Redes sociales                          27    0.157895         0.602339
# Aplicación móvil                        21    0.122807         0.725146
# Ninguna                                 20    0.116959         0.842105
# Aplicación móvil,Redes sociales         13    0.076023         0.918129
# Cuaderno                                 6    0.035088         0.953216

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('214_customer_relationship_tools')
# Out:
# Text(0.5, 1.0, '214_customer_relationship_tools')

# %% [markdown]
# ##HALLAZGOS: El seguimiento de la relación con el cliente en la mayoría de los establecimientos se realiza a través de redes sociales, la aplicación celular dependiendo la sucursal, o algunos optan por que no es necesario dicha relación con el cliente.

# %% [markdown]
# #TABLA 13. Número de competidores.

# %%
compe = Micro_Retailer["145_number_direct_competitors"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table13= freq_tbl(compe)
table13
# Out:
#    145_number_direct_competitors  frequency  percentage  cumulative_perc
# 0                 datos omitidos         68    0.397661         0.397661
# 1                            3.0         16    0.093567         0.491228
# 2                            2.0         16    0.093567         0.584795
# 3                            1.0         16    0.093567         0.678363
# 4                            4.0         14    0.081871         0.760234
# 5                            0.0         12    0.070175         0.830409
# 6                            5.0          8    0.046784         0.877193
# 7                            6.0          6    0.035088         0.912281
# 8                            7.0          5    0.029240         0.941520
# 9                           10.0          3    0.017544         0.959064
# 10                           8.0          3    0.017544         0.976608
# 11                          20.0          2    0.011696         0.988304
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table13[table13['frequency']>1]
Filtro
# Out:
#    145_number_direct_competitors  frequency  percentage  cumulative_perc
# 0                 datos omitidos         68    0.397661         0.397661
# 1                            3.0         16    0.093567         0.491228
# 2                            2.0         16    0.093567         0.584795
# 3                            1.0         16    0.093567         0.678363
# 4                            4.0         14    0.081871         0.760234
# 5                            0.0         12    0.070175         0.830409
# 6                            5.0          8    0.046784         0.877193
# 7                            6.0          6    0.035088         0.912281
# 8                            7.0          5    0.029240         0.941520
# 9                           10.0          3    0.017544         0.959064
# 10                           8.0          3    0.017544         0.976608
# 11                          20.0          2    0.011696         0.988304
# ...

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('145_number_direct_competitors')
Filtro_index
# Out:
#                                frequency  percentage  cumulative_perc
# 145_number_direct_competitors
# datos omitidos                        68    0.397661         0.397661
# 3.0                                   16    0.093567         0.491228
# 2.0                                   16    0.093567         0.584795
# 1.0                                   16    0.093567         0.678363
# 4.0                                   14    0.081871         0.760234
# 0.0                                   12    0.070175         0.830409
# 5.0                                    8    0.046784         0.877193
# 6.0                                    6    0.035088         0.912281
# 7.0                                    5    0.029240         0.941520
# 10.0                                   3    0.017544         0.959064
# 8.0                                    3    0.017544         0.976608
# 20.0                                   2    0.011696         0.988304
# ...

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='145_number_direct_competitors'>

# %%
#Realizamos grafico de dispersión del dataframe filtrado
Filtro_index.plot("frequency", "cumulative_perc", kind="scatter")
# Out:
# <Axes: xlabel='frequency', ylabel='cumulative_perc'>

# %% [markdown]
# ##HALLAZGO: La mayor cantidad de establecimientos presentan un número que va de 1 a 3 competidores en promedio. Son pocos aquellos que presnetan más de 7 competidores.

# %% [markdown]
# #TABLA 14. Tax id.

# %%
tax = Micro_Retailer["19_tax_id"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table14= freq_tbl(tax)
table14
# Out:
#         19_tax_id  frequency  percentage  cumulative_perc
# 0  datos omitidos         71    0.415205         0.415205
# 1             yes         70    0.409357         0.824561
# 2              no         30    0.175439         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table14[table14['frequency']>1]
Filtro
# Out:
#         19_tax_id  frequency  percentage  cumulative_perc
# 0  datos omitidos         71    0.415205         0.415205
# 1             yes         70    0.409357         0.824561
# 2              no         30    0.175439         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('19_tax_id')
Filtro_index
# Out:
#                 frequency  percentage  cumulative_perc
# 19_tax_id
# datos omitidos         71    0.415205         0.415205
# yes                    70    0.409357         0.824561
# no                     30    0.175439         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Números de Identificación del Contribuyente')
# Out:
# Text(0.5, 1.0, 'Números de Identificación del Contribuyente')

# %% [markdown]
# ##HALLAZGO: En su mayoría, los establecimientos son conscientes sobre sus Números de Identificación del  para el pago de sus impuestos.

# %% [markdown]
# #TABLA 15. Herramientas para inventario.

# %%
records = Micro_Retailer["49_inventory_records"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table15= freq_tbl(records)
table15
# Out:
#                                 49_inventory_records  frequency  percentage  \
# 0                                     datos omitidos         61    0.356725
# 1                                           En papel         40    0.233918
# 2               Software especializado + computadora         21    0.122807
# 3                                           En Excel         20    0.116959
# 4                                         No lo hago         18    0.105263
# 5                                  En Excel,En papel          7    0.040936
# 6                                        Mentalmente          1    0.005848
# 7           Aplicación móvil (i.e. App) + smartphone          1    0.005848
# 8                                    En papel,Mental          1    0.005848
# 9  Aplicación móvil (i.e. App) + smartphone,En Excel          1    0.005848
#
#    cumulative_perc
# 0         0.356725
# 1         0.590643
# 2         0.713450
# 3         0.830409
# 4         0.935673
# ...

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table15[table15['frequency']>1]
Filtro
# Out:
#                    49_inventory_records  frequency  percentage  \
# 0                        datos omitidos         61    0.356725
# 1                              En papel         40    0.233918
# 2  Software especializado + computadora         21    0.122807
# 3                              En Excel         20    0.116959
# 4                            No lo hago         18    0.105263
# 5                     En Excel,En papel          7    0.040936
#
#    cumulative_perc
# 0         0.356725
# 1         0.590643
# 2         0.713450
# 3         0.830409
# 4         0.935673
# 5         0.976608

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('49_inventory_records')
Filtro_index
# Out:
#                                       frequency  percentage  cumulative_perc
# 49_inventory_records
# datos omitidos                               61    0.356725         0.356725
# En papel                                     40    0.233918         0.590643
# Software especializado + computadora         21    0.122807         0.713450
# En Excel                                     20    0.116959         0.830409
# No lo hago                                   18    0.105263         0.935673
# En Excel,En papel                             7    0.040936         0.976608

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('Herramientas inventariado')
# Out:
# Text(0.5, 1.0, 'Herramientas inventariado')

# %% [markdown]
# ##HALLAZGO: Sorprendentemente la mayor parte de los comercios siguen usando en papel, notas o apuntes para establecer la compra o reinventariado, seguido por aquellos que usan softwares o computadores y después aquellos que ni siquiera lo hacen.

# %% [markdown]
# #TABLA 16. Revisión mensual finanzas.

# %%
finan = Micro_Retailer["20_reviews_finances_monthly"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table16= freq_tbl(finan)
table16
# Out:
#   20_reviews_finances_monthly  frequency  percentage  cumulative_perc
# 0                         yes         79    0.461988         0.461988
# 1              datos omitidos         63    0.368421         0.830409
# 2                          no         29    0.169591         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table16[table16['frequency']>1]
Filtro
# Out:
#   20_reviews_finances_monthly  frequency  percentage  cumulative_perc
# 0                         yes         79    0.461988         0.461988
# 1              datos omitidos         63    0.368421         0.830409
# 2                          no         29    0.169591         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('20_reviews_finances_monthly')
Filtro_index
# Out:
#                              frequency  percentage  cumulative_perc
# 20_reviews_finances_monthly
# yes                                 79    0.461988         0.461988
# datos omitidos                      63    0.368421         0.830409
# no                                  29    0.169591         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('20_reviews_finances_monthly')
# Out:
# Text(0.5, 1.0, '20_reviews_finances_monthly')

# %% [markdown]
# ##HALLAZGOS: Existe un significante porcentaje de negocios que no revisan mensualmente sus finanzas o lo pasan por alto, sin ser conscientes de las consecuencias que esto podría traer.

# %% [markdown]
# #TABLA 17. Empleados permanentes año pasado.

# %%
empleados = Micro_Retailer["4_number_permanent_employees_last_year"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table17= freq_tbl(empleados)
table17
# Out:
#   4_number_permanent_employees_last_year  frequency  percentage  \
# 0                         datos omitidos         76    0.444444
# 1                                    0.0         32    0.187135
# 2                                    2.0         24    0.140351
# 3                                    1.0         21    0.122807
# 4                                    4.0          8    0.046784
# 5                                    3.0          6    0.035088
# 6                                    6.0          2    0.011696
# 7                                   45.0          1    0.005848
# 8                                    5.0          1    0.005848
#
#    cumulative_perc
# 0         0.444444
# 1         0.631579
# 2         0.771930
# 3         0.894737
# 4         0.941520
# 5         0.976608
# 6         0.988304
# 7         0.994152
# 8         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table17[table17['frequency']>1]
Filtro
# Out:
#   4_number_permanent_employees_last_year  frequency  percentage  \
# 0                         datos omitidos         76    0.444444
# 1                                    0.0         32    0.187135
# 2                                    2.0         24    0.140351
# 3                                    1.0         21    0.122807
# 4                                    4.0          8    0.046784
# 5                                    3.0          6    0.035088
# 6                                    6.0          2    0.011696
#
#    cumulative_perc
# 0         0.444444
# 1         0.631579
# 2         0.771930
# 3         0.894737
# 4         0.941520
# 5         0.976608
# 6         0.988304

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('4_number_permanent_employees_last_year')
Filtro_index
# Out:
#                                         frequency  percentage  cumulative_perc
# 4_number_permanent_employees_last_year
# datos omitidos                                 76    0.444444         0.444444
# 0.0                                            32    0.187135         0.631579
# 2.0                                            24    0.140351         0.771930
# 1.0                                            21    0.122807         0.894737
# 4.0                                             8    0.046784         0.941520
# 3.0                                             6    0.035088         0.976608
# 6.0                                             2    0.011696         0.988304

# %%
#Realizamos grafico de área del dataframe filtrado
Filtro_index.plot(kind='area', figsize=(10,4),alpha = 0.5)
# Out:
# <Axes: xlabel='4_number_permanent_employees_last_year'>

# %% [markdown]
# ##HALLAZGOS: En su mayoría la cantidad de empleados permannetes hace un año se encuentran entre 1 a 2 personas.

# %% [markdown]
# #TABLA 18. Empleados permanentes en la actualidad.

# %%
emplo = Micro_Retailer["2_current_permanent_employees"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table18= freq_tbl(emplo)
table18
# Out:
#   2_current_permanent_employees  frequency  percentage  cumulative_perc
# 0                datos omitidos         60    0.350877         0.350877
# 1                           1.0         33    0.192982         0.543860
# 2                           2.0         26    0.152047         0.695906
# 3                           0.0         26    0.152047         0.847953
# 4                           3.0         11    0.064327         0.912281
# 5                           4.0         10    0.058480         0.970760
# 6                           5.0          3    0.017544         0.988304
# 7                          50.0          1    0.005848         0.994152
# 8                           6.0          1    0.005848         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table18[table18['frequency']>1]
Filtro
# Out:
#   2_current_permanent_employees  frequency  percentage  cumulative_perc
# 0                datos omitidos         60    0.350877         0.350877
# 1                           1.0         33    0.192982         0.543860
# 2                           2.0         26    0.152047         0.695906
# 3                           0.0         26    0.152047         0.847953
# 4                           3.0         11    0.064327         0.912281
# 5                           4.0         10    0.058480         0.970760
# 6                           5.0          3    0.017544         0.988304

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('2_current_permanent_employees')
Filtro_index
# Out:
#                                frequency  percentage  cumulative_perc
# 2_current_permanent_employees
# datos omitidos                        60    0.350877         0.350877
# 1.0                                   33    0.192982         0.543860
# 2.0                                   26    0.152047         0.695906
# 0.0                                   26    0.152047         0.847953
# 3.0                                   11    0.064327         0.912281
# 4.0                                   10    0.058480         0.970760
# 5.0                                    3    0.017544         0.988304

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('2_current_permanent_employees')
# Out:
# Text(0.5, 1.0, '2_current_permanent_employees')

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
# Out:
# <Axes: xlabel='2_current_permanent_employees'>

# %% [markdown]
# ##HALLAZGOS: Al igual que el año anterior, los patrones de empleados permannetes se mantuvieron en su mayoría de 1 a 2 empleados fijos.

# %% [markdown]
# #TABLA 19. Confidencialidad.

# %%
conf = Micro_Retailer["le_comento_que_toda_esta_informacin_es_confidencial"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table19= freq_tbl(conf)
table19
# Out:
#   le_comento_que_toda_esta_informacin_es_confidencial  frequency  percentage  \
# 0                                                yes         164    0.959064
# 1                                                 no           7    0.040936
#
#    cumulative_perc
# 0         0.959064
# 1         1.000000

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table19[table19['frequency']>1]
Filtro
# Out:
#   le_comento_que_toda_esta_informacin_es_confidencial  frequency  percentage  \
# 0                                                yes         164    0.959064
# 1                                                 no           7    0.040936
#
#    cumulative_perc
# 0         0.959064
# 1         1.000000

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('le_comento_que_toda_esta_informacin_es_confidencial')
Filtro_index
# Out:
#                                                     frequency  percentage  \
# le_comento_que_toda_esta_informacin_es_confiden...
# yes                                                       164    0.959064
# no                                                          7    0.040936
#
#                                                     cumulative_perc
# le_comento_que_toda_esta_informacin_es_confiden...
# yes                                                        0.959064
# no                                                         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title("le_comento_que_toda_esta_informacin_es_confidencial")
# Out:
# Text(0.5, 1.0, 'le_comento_que_toda_esta_informacin_es_confidencial')

# %% [markdown]
# ##HALLAZGOS: Sí hubo registro de personas a las que no les comentaron que el uso de esta información sería de caracter confidencial.

# %% [markdown]
# #TABLA 20. Tipo de establecimiento.

# %%
store = Micro_Retailer["232_type_of_store"].fillna("datos omitidos")

# %%
#Obtengo un análisis univariado de una variable categórica en específico
table20= freq_tbl(store)
table20
# Out:
#                   232_type_of_store  frequency  percentage  cumulative_perc
# 0    Grocery store (aka. nanostore)         52    0.304094         0.304094
# 1   Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# 2                    Dairy products         10    0.058480         0.543860
# 3                         Cafeteria          6    0.035088         0.578947
# 4                      Butcher shop          6    0.035088         0.614035
# ..                              ...        ...         ...              ...
# 59                          joyeria          1    0.005848         0.976608
# 60                         dulceria          1    0.005848         0.982456
# 61                             Ropa          1    0.005848         0.988304
# 62                       Ferretería          1    0.005848         0.994152
# 63         productos tradicionales           1    0.005848         1.000000
#
# [64 rows x 4 columns]

# %%
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= table20[table20['frequency']>1]
Filtro
# Out:
#                  232_type_of_store  frequency  percentage  cumulative_perc
# 0   Grocery store (aka. nanostore)         52    0.304094         0.304094
# 1  Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# 2                   Dairy products         10    0.058480         0.543860
# 3                        Cafeteria          6    0.035088         0.578947
# 4                     Butcher shop          6    0.035088         0.614035
# 5    Produce (fruits & vegetables)          4    0.023392         0.637427
# 6               Handmade products           2    0.011696         0.649123
# 7                       Papelería           2    0.011696         0.660819
# 8                         objetos           2    0.011696         0.672515
# 9                      Ferretería           2    0.011696         0.684211

# %%
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('232_type_of_store')
Filtro_index
# Out:
#                                  frequency  percentage  cumulative_perc
# 232_type_of_store
# Grocery store (aka. nanostore)          52    0.304094         0.304094
# Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# Dairy products                          10    0.058480         0.543860
# Cafeteria                                6    0.035088         0.578947
# Butcher shop                             6    0.035088         0.614035
# Produce (fruits & vegetables)            4    0.023392         0.637427
# Handmade products                        2    0.011696         0.649123
# Papelería                                2    0.011696         0.660819
# objetos                                  2    0.011696         0.672515
# Ferretería                               2    0.011696         0.684211

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
plt.title('232_type_of_store')
# Out:
# Text(0.5, 1.0, '232_type_of_store')

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(10,4))
# Out:
# <Axes: xlabel='232_type_of_store'>

# %% [markdown]
# ##HALLAZGOS: En gran parte de los participantes de esta encuenta eran de servicios de restaurante o pequeños restaurantes conocidos como fonditas, de ahí tiendas de productos diarios o tipo miscelaneas, cafeterías, mientras que las ferreterías fueron minoría con la menor presencia.
